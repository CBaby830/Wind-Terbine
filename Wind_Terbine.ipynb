# %%
import matplotlib.pyplot as plt  # Library for creating plots and visualizations
import numpy as np  # Library for numerical computing
import pandas as pd  # Library for data manipulation and analysis
import seaborn as sns  # Library for creating plots and visualizations

# %%
df=pd.read_csv(r"Data_Set_WT.csv")
print(df.head(5))
# Out:
#          date  Wind_speed     Power  Nacelle_ambient_temperature  \
# 0  2023-02-01    7.799746  2.294532                    32.478243
# 1  2023-04-29   43.441611  0.773574                   -55.547015
# 2  2023-07-27   14.073105  2.071047                    39.680000
# 3  2023-06-05   41.162919  0.148410                   -53.617603
# 4  2023-05-26   18.876468  2.946286                    12.629549
#
#    Generator_bearing_temperature  Gear_oil_temperature  Ambient_temperature  \
# 0                      85.596520             64.418706            34.690590
# 1                      59.187505            100.447116           -18.129465
# 2                      80.242633             49.515000            29.550796
# 3                      46.304320            111.135974            -2.860951
# 4                      88.603457             83.707096            41.200000
#
#    Rotor_Speed  Nacelle_temperature  Bearing_temperature)  Generator_speed  \
# ...

# %%
df.tail(5)
# Out:
#             date  Wind_speed     Power  Nacelle_ambient_temperature  \
# 3595  2023-09-29    0.031000  5.386088                    52.884016
# 3596  2023-03-10    3.198901  2.575183                     4.174863
# 3597  2023-11-02    2.975921  2.992836                     6.779750
# 3598  2023-06-11   19.659749  2.584704                     2.689192
# 3599  2023-10-18   24.415199  0.000000                     1.139749
#
#       Generator_bearing_temperature  Gear_oil_temperature  \
# 3595                     131.454578            109.951198
# 3596                      73.356938             57.393179
# 3597                      82.373785             61.001013
# 3598                      76.409319             73.347783
# 3599                      74.703482             80.577547
#
#       Ambient_temperature  Rotor_Speed  Nacelle_temperature  \
# 3595            83.532536   369.680822            95.807311
# 3596            23.280782    53.788448            48.448129
# ...

# %%
df.dtypes
# Out:
# date                              object
# Wind_speed                       float64
# Power                            float64
# Nacelle_ambient_temperature      float64
# Generator_bearing_temperature    float64
# Gear_oil_temperature             float64
# Ambient_temperature              float64
# Rotor_Speed                      float64
# Nacelle_temperature              float64
# Bearing_temperature)             float64
# Generator_speed                  float64
# Yaw_angle                        float64
# Wind_direction                   float64
# Wheel_hub_temperature            float64
# Gear_box_inlet_temperature       float64
# Failure_status                    object
# dtype: object

# %%
print(df.shape)
# Out:
# (3600, 16)

# %%
df.describe()
# Out:
#         Wind_speed        Power  Nacelle_ambient_temperature  \
# count  3600.000000  3600.000000                  3600.000000
# mean     16.391655     3.313057                    11.441843
# std      13.203737     2.611270                    43.560698
# min      -5.229383     0.000000                  -260.914548
# 25%       6.378326     2.215392                     1.128094
# 50%      13.871383     2.697724                     9.766350
# 75%      21.722268     3.241911                    28.031111
# max      53.878126    11.884147                   290.660714
#
#        Generator_bearing_temperature  Gear_oil_temperature  \
# count                    3600.000000           3600.000000
# mean                       84.070038             84.278844
# std                        28.291756             23.012128
# min                         9.918990             49.515000
# 25%                        72.599362             65.971776
# ...

# %%
df.rename(columns={'Bearing_temperature)': 'Bearing_temperature'}, inplace=True)

# %%
p=df.Failure_status.mode()
print("mode",p)
# Out:
# mode 0    No_failure
# Name: Failure_status, dtype: object

# %%
df.Wind_speed.mean()
# Out:
# 16.3916545183625

# %%
df.Wind_speed.median()
# Out:
# 13.871383285

# %%
df.Wind_speed.mode()
# Out:
# 0    24.75
# Name: Wind_speed, dtype: float64

# %%
df.Power.mean()
# Out:
# 3.3130573062163893

# %%
df.Power.median()
# Out:
# 2.6977236905

# %%
df.Power.mode()
# Out:
# 0    1.982
# Name: Power, dtype: float64

# %%
print(df.Nacelle_ambient_temperature.mean())
print(df.Nacelle_ambient_temperature.median())
print(df.Nacelle_ambient_temperature.mode(),"mode")
# Out:
# 11.441842503712778
# 9.7663502035
# 0    39.68
# Name: Nacelle_ambient_temperature, dtype: float64 mode

# %%
print(df.Generator_bearing_temperature.mean())
print(df.Generator_bearing_temperature.median())
print(df.Generator_bearing_temperature.mode(),"mode")
# Out:
# 84.07003792808472
# 83.107151135
# 0         9.918990
# 1         9.926540
# 2        10.109630
# 3        10.279401
# 4        10.329176
#            ...
# 3595    143.266491
# 3596    143.412819
# 3597    143.432185
# 3598    143.516806
# 3599    143.560021
# Name: Generator_bearing_temperature, Length: 3600, dtype: float64 mode

# %%
df.Generator_bearing_temperature.mode()
# Out:
# 0         9.918990
# 1         9.926540
# 2        10.109630
# 3        10.279401
# 4        10.329176
#            ...
# 3595    143.266491
# 3596    143.412819
# 3597    143.432185
# 3598    143.516806
# 3599    143.560021
# Name: Generator_bearing_temperature, Length: 3600, dtype: float64

# %%
print(df.Gear_oil_temperature.mode(),"mode")
print(df.Ambient_temperature.mode(),"mode")
print(df.Rotor_Speed.mode(),"mode")
print(df.Nacelle_temperature.mode(),"mode")
print(df.Bearing_temperature.mode(),"mode")
print(df.Generator_speed.mode(),"mode")
# Out:
# 0    89.127
# Name: Gear_oil_temperature, dtype: float64 mode
# 0   -20.6
# Name: Ambient_temperature, dtype: float64 mode
# 0    309.0
# Name: Rotor_Speed, dtype: float64 mode
# 0    61.8
# Name: Nacelle_temperature, dtype: float64 mode
# 0    71.4
# Name: Bearing_temperature, dtype: float64 mode
# 0    1782.0
# Name: Generator_speed, dtype: float64 mode

# %%
print(df.Yaw_angle.mode(),"mode")
print(df.Wind_direction.mode(),"mode")
print(df.Wheel_hub_temperature.mode(),"mode")
print(df.Gear_box_inlet_temperature.mode(),"mode")
print(df.Failure_status.mode(),"mode")
# Out:
# 0    0.0
# Name: Yaw_angle, dtype: float64 mode
# 0      -413.410814
# 1      -397.638317
# 2      -388.782710
# 3      -374.769751
# 4      -368.547908
#            ...
# 3595    572.760146
# 3596    576.535540
# 3597    598.386927
# 3598    618.492562
# 3599    631.969292
# Name: Wind_direction, Length: 3600, dtype: float64 mode
# 0    79.44
# Name: Wheel_hub_temperature, dtype: float64 mode
# 0    9.903
# Name: Gear_box_inlet_temperature, dtype: float64 mode
# 0    No_failure
# Name: Failure_status, dtype: object mode

# %%
df.isnull().sum()
# Out:
# date                             0
# Wind_speed                       0
# Power                            0
# Nacelle_ambient_temperature      0
# Generator_bearing_temperature    0
# Gear_oil_temperature             0
# Ambient_temperature              0
# Rotor_Speed                      0
# Nacelle_temperature              0
# Bearing_temperature              0
# Generator_speed                  0
# Yaw_angle                        0
# Wind_direction                   0
# Wheel_hub_temperature            0
# Gear_box_inlet_temperature       0
# Failure_status                   0
# dtype: int64

# %%
print(df.Wind_speed.var())
# Out:
# 174.33866705812287

# %%
print(max(df.Wind_speed) - min(df.Wind_speed))
# Out:
# 59.107508550000006

# %%
print(df.Wind_speed.std())
# Out:
# 13.203736859621326

# %%
print(df.Power.var(),"Power")
print(df.Nacelle_ambient_temperature.var(),"Nacelle_ambient_temperature")
print(df.Generator_bearing_temperature.var(),"Generator_bearing_temperature")
print(df.Gear_oil_temperature.var(),"Gear_oil_temperature")
print(df.Ambient_temperature.var(),"Ambient_temperature")
print(df.Rotor_Speed.var(),"Rotor_Speed")
print(df.Nacelle_temperature.var(),"Nacelle_temperature")
print(df.Bearing_temperature.var(),"Bearing_temperature)")
print(df.Generator_speed.var(),"Generator_speed")
print(df.Yaw_angle.var(),"Yaw_angle")
print(df.Wind_direction.var(),"Wind_direction")
print(df.Wheel_hub_temperature.var(),"Wheel_hub_temperature")
print(df.Gear_box_inlet_temperature.var(),"Gear_box_inlet_temperature")
#print(df.Failure_status.var(),"Failure_status")
# Out:
# 6.8187336150285764 Power
# 1897.5343990679805 Nacelle_ambient_temperature
# 800.4234695519391 Generator_bearing_temperature
# 529.5580516695428 Gear_oil_temperature
# 895.3631999101146 Ambient_temperature
# 16031.259010387988 Rotor_Speed
# 708.6076214208285 Nacelle_temperature
# 978.0494363244059 Bearing_temperature)
# 302699.392074937 Generator_speed
# 3122.529532040969 Yaw_angle
# 11983.029155672704 Wind_direction
# 3292.2068810507135 Wheel_hub_temperature
# 895.0577083717385 Gear_box_inlet_temperature

# %%
print(max(df.Power)-min(df.Power))
# Out:
# 11.88414738

# %%
print(max(df.Nacelle_ambient_temperature)-min(df.Nacelle_ambient_temperature),"Nacelle_ambient_temperature")
print(max(df.Generator_bearing_temperature)-min(df.Generator_bearing_temperature),"Generator_bearing_temperature")
print(max(df.Gear_oil_temperature)-min(df.Gear_oil_temperature),"Gear_oil_temperature")
print(max(df.Ambient_temperature)-min(df.Ambient_temperature),"Ambient_temperature")
print(max(df.Rotor_Speed)-min(df.Rotor_Speed),"Rotor_Speed")
print(max(df.Nacelle_temperature)-min(df.Nacelle_temperature),"Nacelle_temperature")
print(max(df.Bearing_temperature-min(df.Bearing_temperature)),"Bearing_temperature)")
print(max(df.Generator_speed)-min(df.Generator_speed),"Generator_speed")
print(max(df.Yaw_angle)-min(df.Yaw_angle),"Yaw_angle")
print(max(df.Wind_direction)-min(df.Wind_direction),"Wind_direction")
print(max(df.Wheel_hub_temperature)-min(df.Wheel_hub_temperature),"Wheel_hub_temperature")
print(max(df.Gear_box_inlet_temperature)-min(df.Gear_box_inlet_temperature),"Gear_box_inlet_temperature")
# Out:
# 551.5752620000001 Nacelle_ambient_temperature
# 133.641030435 Generator_bearing_temperature
# 79.20858199999999 Gear_oil_temperature
# 108.14104700000001 Ambient_temperature
# 463.054936482 Rotor_Speed
# 142.14474091 Nacelle_temperature
# 142.72761284 Bearing_temperature)
# 3963.618966 Generator_speed
# 178.5197945 Yaw_angle
# 1045.380106 Wind_direction
# 208.35261323999998 Wheel_hub_temperature
# 118.8017527 Gear_box_inlet_temperature

# %%
print(df.Wind_speed.skew())
# Out:
# 0.8071795187561859

# %%
print(df.Power.skew(),"Power")
# Out:
# 1.6032466241458547 Power

# %%
print(df.Nacelle_ambient_temperature.skew(),"Nacelle_ambient_temperature")
print(df.Generator_bearing_temperature.skew(),"Generator_bearing_temperature")
print(df.Gear_oil_temperature.skew(),"Gear_oil_temperature")
print(df.Ambient_temperature.skew(),"Ambient_temperature")
print(df.Rotor_Speed.skew(),"Rotor_Speed")
print(df.Nacelle_temperature.skew(),"Nacelle_temperature")
print(df.Bearing_temperature.skew(),"Bearing_temperature)")
print(df.Generator_speed.skew(),"Generator_speed")
print(df.Yaw_angle.skew(),"Yaw_angle")
print(df.Wind_direction.skew(),"Wind_direction")
print(df.Wheel_hub_temperature.skew(),"Wheel_hub_temperature")
print(df.Gear_box_inlet_temperature.skew(),"Gear_box_inlet_temperature")
#print(df.Failure_status.skew(),"Failure_status")
# Out:
# 0.9315901067102894 Nacelle_ambient_temperature
# -0.1275176983686987 Generator_bearing_temperature
# 0.4319287496477263 Gear_oil_temperature
# 0.8991069153710165 Ambient_temperature
# 0.37915619198615963 Rotor_Speed
# -0.1709684482212046 Nacelle_temperature
# 0.07746160839039812 Bearing_temperature)
# 0.09179907534599453 Generator_speed
# 0.9720167173250933 Yaw_angle
# 0.9426563119383194 Wind_direction
# -0.0575011148304697 Wheel_hub_temperature
# 1.8564394710364382 Gear_box_inlet_temperature

# %%
df.Wind_speed.kurt()
# Out:
# -0.3660811169464133

# %%
print(df.Power.kurt(),"Power")
print(df.Nacelle_ambient_temperature.kurt(),"Nacelle_ambient_temperature")
print(df.Generator_bearing_temperature.kurt(),"Generator_bearing_temperature")
print(df.Gear_oil_temperature.kurt(),"Gear_oil_temperature")
print(df.Ambient_temperature.kurt(),"Ambient_temperature")
print(df.Rotor_Speed.kurt(),"Rotor_Speed")
print(df.Nacelle_temperature.kurt(),"Nacelle_temperature")
print(df.Bearing_temperature.kurt(),"Bearing_temperature)")
print(df.Generator_speed.kurt(),"Generator_speed")
print(df.Yaw_angle.kurt(),"Yaw_angle")
print(df.Wind_direction.kurt(),"Wind_direction")
print(df.Wheel_hub_temperature.kurt(),"Wheel_hub_temperature")
print(df.Gear_box_inlet_temperature.kurt(),"Gear_box_inlet_temperature")
#print(df..kurt(),"")
#print(df..kurt(),"")
# Out:
# 2.1040388341855207 Power
# 4.691112319890928 Nacelle_ambient_temperature
# 0.3942116919834273 Generator_bearing_temperature
# -1.1371245847232432 Gear_oil_temperature
# -0.21691287125035474 Ambient_temperature
# -0.7048684287163924 Rotor_Speed
# 0.2537134559755141 Nacelle_temperature
# -0.12184351076877409 Bearing_temperature)
# 0.0024158526231676802 Generator_speed
# -0.5639523210214925 Yaw_angle
# 3.972304250652627 Wind_direction
# -0.8832895246541685 Wheel_hub_temperature
# 1.8366456491992773 Gear_box_inlet_temperature

# %%
plt.hist(df.Wind_speed)
# Out:
# (array([223., 693., 678., 821., 434., 129.,   9., 384., 226.,   3.]),
#  array([-5.2293828 ,  0.68136806,  6.59211891, 12.50286977, 18.41362062,
#         24.32437148, 30.23512233, 36.14587318, 42.05662404, 47.9673749 ,
#         53.87812575]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df.Wind_speed) 
plt.show()
plt.hist(df.Power)
plt.show()
plt.hist(df.Nacelle_ambient_temperature)
plt.show()
plt.hist(df.Generator_bearing_temperature )
plt.show()
plt.hist(df.Gear_oil_temperature )
plt.show()
plt.hist(df.Ambient_temperature)
plt.show()
plt.hist(df.Rotor_Speed)
plt.show()
plt.hist(df.Nacelle_temperature)
plt.show()
plt.hist(df.Bearing_temperature )
plt.show()
plt.hist(df.Generator_speed)
plt.show()
plt.hist(df.Yaw_angle )
plt.show()
plt.hist(df.Wind_direction)
plt.show()
plt.hist(df.Wheel_hub_temperature)
plt.show()
plt.hist(df.Gear_box_inlet_temperature)
plt.show()

# %%
sns.boxplot(x=df['Wind_speed']) 
plt.show()
sns.boxplot(x=df['Power'])
plt.show()
sns.boxplot(x=df['Nacelle_ambient_temperature'])
plt.show()
sns.boxplot(x=df['Generator_bearing_temperature'])
plt.show()
sns.boxplot(x=df['Gear_oil_temperature'])
plt.show()
sns.boxplot(x=df['Ambient_temperature'])
plt.show()
sns.boxplot(x=df['Rotor_Speed'])
plt.show()
sns.boxplot(x=df['Nacelle_temperature'])
plt.show()
sns.boxplot(x=df['Bearing_temperature'] )
plt.show()
sns.boxplot(x=df['Generator_speed'])
plt.show()
sns.boxplot(x=df['Yaw_angle'])
plt.show()
sns.boxplot(x=df['Wind_direction'])
plt.show()
sns.boxplot(x=df['Wheel_hub_temperature'])
plt.show()
sns.boxplot(x=df['Gear_box_inlet_temperature'])
plt.show()

# %%
df=df.corr(numeric_only=True)
sns.heatmap(df.corr(), annot = True, cmap = "coolwarm") 
#annot = True This means that the actual correlation values will be displayed inside the heatmap cells. 
#If set to False, the heatmap will only show colors without numerical values.
plt.title("Correlation Heatmap - Cars Dataset")
plt.show()

# %%
df_numeric = df.select_dtypes(include=['number'])
df_numeric.skew()
# Out:
# Wind_speed                       0.807180
# Power                            1.603247
# Nacelle_ambient_temperature      0.931590
# Generator_bearing_temperature   -0.127518
# Gear_oil_temperature             0.431929
# Ambient_temperature              0.899107
# Rotor_Speed                      0.379156
# Nacelle_temperature             -0.170968
# Bearing_temperature)             0.077462
# Generator_speed                  0.091799
# Yaw_angle                        0.972017
# Wind_direction                   0.942656
# Wheel_hub_temperature           -0.057501
# Gear_box_inlet_temperature       1.856439
# dtype: float64
